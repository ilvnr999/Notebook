# %% [markdown]
# <a href="https://colab.research.google.com/github/ilvnr999/Notebook/blob/main/ML_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #sklearn ML操作

# %% [markdown]
# ##簡易流程

# %% [markdown]
# 數入data並檢視

# %%
import pandas as pd
file_path = '/content/melb_data.csv.zip'
df = pd.read_csv(file_path)

df.describe()
#df.head()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# 處理data中的數值
#
# * 清理缺失值
#
# * 選取感興趣的column觀察

# %%
df.dropna(axis=0)
feature = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X = df[feature]
y = df['Price']
X.describe()
# Out:
#               Rooms      Bathroom       Landsize     Lattitude    Longtitude
# count  13580.000000  13580.000000   13580.000000  13580.000000  13580.000000
# mean       2.937997      1.534242     558.416127    -37.809203    144.995216
# std        0.955748      0.691712    3990.669241      0.079260      0.103916
# min        1.000000      0.000000       0.000000    -38.182550    144.431810
# 25%        2.000000      1.000000     177.000000    -37.856822    144.929600
# 50%        3.000000      1.000000     440.000000    -37.802355    145.000100
# 75%        3.000000      2.000000     651.000000    -37.756400    145.058305
# max       10.000000      8.000000  433014.000000    -37.408530    145.526350

# %% [markdown]
# 分割驗證集

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %% [markdown]
# 建立model 透過sklearn

# %% [markdown]
# 決策樹

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=1)
model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %% [markdown]
# 隨機森林

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))

# %% [markdown]
# 驗證
#
# 使用MAE

# %%
from sklearn.metrics import mean_absolute_error
val_predictions = model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 250429.6127638684

# %% [markdown]
# ## 搜索適合的模型參數大小
#
# 決策樹可調整模型最大葉子數量來搜索適合的模型大小深度
#
# 避免overfitting underfitting

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  354662
# Max leaf nodes: 50  		 Mean Absolute Error:  266447
# Max leaf nodes: 500  		 Mean Absolute Error:  231301
# Max leaf nodes: 5000  		 Mean Absolute Error:  248846
